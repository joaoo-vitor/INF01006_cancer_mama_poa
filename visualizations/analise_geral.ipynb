# %%
import pandas as pd


df_aq_rs_colo = pd.read_csv("../datasets/AQRS25colo_agregado.csv")
df_aq_rs_mama = pd.read_csv("../datasets/AQRS25mama_agregado.csv")


df_ar_rs_colo = pd.read_csv("../datasets/ARRS25colo_agregado.csv")
df_ar_rs_mama = pd.read_csv("../datasets/ARRS25mama_agregado.csv")

df_rd_rs_colo = pd.read_csv("../datasets/RDRS25colo_agregado.csv")
df_rd_rs_mama = pd.read_csv("../datasets/RDRS25mama_agregado.csv")
# Out:
# C:\Users\joaoo\AppData\Local\Temp\ipykernel_26616\1839502967.py:5: DtypeWarning: Columns (0: AP_CIDCAS) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aq_rs_mama = pd.read_csv("../datasets/AQRS25mama_agregado.csv")

# %% [markdown]
# # Valores dos dados (2025)

# %% [markdown]
# ### Quimioterapia Colo

# %%
for column in df_aq_rs_colo.columns:
    print("Campos encontrados para coluna ", column)
    print(df_aq_rs_colo[column].unique(), "\n")
# Out:
# Campos encontrados para coluna  AP_MVM
# [202501 202502 202503 202504 202505 202506 202507 202508 202509 202510
#  202511 202512]
#
# Campos encontrados para coluna  AP_CONDIC
# <ArrowStringArray>
# ['Pacto de Gestão', 'Estado Pleno']
# Length: 2, dtype: str
#
# Campos encontrados para coluna  AP_GESTAO
# <ArrowStringArray>
# [           'Porto Alegre',           'Caxias do Sul',
#  'Município ignorado - RS',                  'Canoas',
#             'São Leopoldo',       'Santa Cruz do Sul',
#          'Bento Gonçalves',                 'Pelotas',
#                  'Lajeado',        'Cachoeira do Sul',
#                'Carazinho',              'Santa Rosa',
#                'São Borja']
# Length: 13, dtype: str
#
# Campos encontrados para coluna  AP_CODUNI
# [2237571 2237601 2223538 2261057 2263858 2232014 2232022 2246929 2261987
#  2232995 2255936 2248190 2241021 2707918 2252694 2244306 2252287 2227932
#  2262568 2259907 2237253 2253054 2246988 2266474 2262274 2254611 2244357
# ...

# %% [markdown]
# ### Quimioterapia Mama

# %%
for column in df_aq_rs_mama.columns:
    print("Campos encontrados para coluna ", column)
    print(df_aq_rs_mama[column].unique(), "\n")
# Out:
# Campos encontrados para coluna  AP_MVM
# [202501 202502 202503 202504 202505 202506 202507 202508 202509 202510
#  202511 202512]
#
# Campos encontrados para coluna  AP_CONDIC
# <ArrowStringArray>
# ['Estado Pleno', 'Pacto de Gestão']
# Length: 2, dtype: str
#
# Campos encontrados para coluna  AP_GESTAO
# <ArrowStringArray>
# ['Município ignorado - RS',            'Porto Alegre',
#            'Caxias do Sul',        'Cachoeira do Sul',
#        'Santa Cruz do Sul',         'Bento Gonçalves',
#                  'Pelotas',            'São Leopoldo',
#                  'Lajeado',                  'Canoas',
#                'Carazinho',              'Santa Rosa',
#                'São Borja']
# Length: 13, dtype: str
#
# Campos encontrados para coluna  AP_CODUNI
# [2232995 2237253 2237571 2223538 2237601 2244357 2246929 2248190 2261057
#  2266474 2693801 2255936 2248204 2261987 2707918 2241021 2252694 2232022
#  2244306 2263858 2252287 2227932 2246988 2259907 2232014 2262274 2223546
# ...

# %% [markdown]
# ### Radiografia Colo

# %%
for column in df_ar_rs_colo.columns:
    print("Campos encontrados para coluna ", column)
    print(df_ar_rs_colo[column].unique(), "\n")
# Out:
# Campos encontrados para coluna  AP_MVM
# [202501 202502 202503 202504 202505 202506 202507 202508 202509 202510
#  202511 202512]
#
# Campos encontrados para coluna  AP_CONDIC
# <ArrowStringArray>
# ['Pacto de Gestão', 'Estado Pleno']
# Length: 2, dtype: str
#
# Campos encontrados para coluna  AP_GESTAO
# <ArrowStringArray>
# [           'Porto Alegre',            'São Leopoldo',
#               'Santa Rosa', 'Município ignorado - RS',
#            'Caxias do Sul',                 'Pelotas',
#                  'Lajeado',       'Santa Cruz do Sul',
#          'Bento Gonçalves']
# Length: 9, dtype: str
#
# Campos encontrados para coluna  AP_CODUNI
# [2237601 2237253 2232022 2254611 2246988 2223538 2253054 2248190 2232995
#  2262568 2252287 2255936 2244306 2241021 2261057 2252694 2261987 2707918
#  2237571 2246929]
#
# Campos encontrados para coluna  AP_AUTORIZ
# [4325201355410 4325201402071 4325201352990 ... 4325207020618 4325219376786
#  4325216642065]
#
# ...

# %% [markdown]
# ### Radiografia Mama

# %%
for column in df_ar_rs_mama.columns:
    print("Campos encontrados para coluna ", column)
    print(df_ar_rs_mama[column].unique(), "\n")
# Out:
# Campos encontrados para coluna  AP_MVM
# [202501 202502 202503 202504 202505 202506 202507 202508 202509 202510
#  202511 202512]
#
# Campos encontrados para coluna  AP_CONDIC
# <ArrowStringArray>
# ['Estado Pleno', 'Pacto de Gestão']
# Length: 2, dtype: str
#
# Campos encontrados para coluna  AP_GESTAO
# <ArrowStringArray>
# ['Município ignorado - RS',                 'Lajeado',
#             'Porto Alegre',       'Santa Cruz do Sul',
#             'São Leopoldo',           'Caxias do Sul',
#               'Santa Rosa',                 'Pelotas',
#          'Bento Gonçalves']
# Length: 9, dtype: str
#
# Campos encontrados para coluna  AP_CODUNI
# [2261987 2252287 2237253 2255936 2232022 2246988 2223538 2262568 2254611
#  2253054 2252694 2237601 2261057 2707918 2241021 2244306 2248190 2232995
#  2237571 2246929]
#
# Campos encontrados para coluna  AP_AUTORIZ
# [4325201309308 4325200681770 4324204814534 ... 4325219322963 4325224880053
#  4325207329938]
#
# ...

# %% [markdown]
# ### Internações Colo

# %%
for column in df_rd_rs_colo.columns:
    print("Campos encontr}ados para coluna ", column)
    print(df_rd_rs_colo[column].unique(), "\n")
# Out:
# Campos encontr}ados para coluna  UF_ZI
# <ArrowStringArray>
# ['Rio Grande do Sul - Gestão estadual',                    'Cachoeira do Sul',
#                               'Canoas',                       'Caxias do Sul',
#                              'Lajeado',                             'Pelotas',
#                         'Porto Alegre',                   'Santa Cruz do Sul',
#                         'São Leopoldo',                     'Sapucaia do Sul',
#                            'Carazinho',                       'Novo Hamburgo',
#                            'São Borja',                     'Serafina Corrêa',
#                       'Arroio do Meio',                     'Bento Gonçalves',
#                                'Giruá',                             'Gramado',
#                               'Quaraí',                          'Santa Rosa',
#                       'Venâncio Aires',                           'Encantado',
# ...

# %% [markdown]
# ### Internações Mama

# %%
for column in df_rd_rs_mama.columns:
    print("Campos encontrados para coluna ", column)
    print(df_rd_rs_mama[column].unique(), "\n")
# Out:
# Campos encontrados para coluna  UF_ZI
# <ArrowStringArray>
# ['Rio Grande do Sul - Gestão estadual',                     'Bento Gonçalves',
#                     'Cachoeira do Sul',                              'Canoas',
#                            'Carazinho',                       'Caxias do Sul',
#                                'Giruá',                             'Gramado',
#                              'Lajeado',                     'Nova Petrópolis',
#                        'Novo Hamburgo',                             'Pelotas',
#                         'Porto Alegre',                           'Progresso',
#                    'Santa Cruz do Sul',              'Sant'Ana do Livramento',
#                           'Santa Rosa',                        'São Leopoldo',
#                      'Sapucaia do Sul',                             'Vacaria',
#                               'Esteio',                           'São Borja',
# ...
