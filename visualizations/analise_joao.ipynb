# %%
import pandas as pd


df_aq_rs_colo = pd.read_csv("../datasets/AQRS25colo_agregado.csv")
df_aq_rs_mama = pd.read_csv("../datasets/AQRS25mama_agregado.csv")


df_ar_rs_colo = pd.read_csv("../datasets/ARRS25colo_agregado.csv")
df_ar_rs_mama = pd.read_csv("../datasets/ARRS25mama_agregado.csv")

df_rd_rs_colo = pd.read_csv("../datasets/RDRS25colo_agregado.csv")
df_rd_rs_mama = pd.read_csv("../datasets/RDRS25mama_agregado.csv")
# Out:
# C:\Users\joaoo\AppData\Local\Temp\ipykernel_16628\1839502967.py:5: DtypeWarning: Columns (0: AP_CIDCAS) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aq_rs_mama = pd.read_csv("../datasets/AQRS25mama_agregado.csv")

# %%
from plots import *
plot_chemotherapies_by_month(df_ar_rs_mama)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Quimioterapias realizadas em Porto Alegre por Mês (2025)\n(Câncer de Mama)'}, xlabel='Mês de Processamento (2025)', ylabel='Número de Procedimentos'>)

# %%
plot_chemotherapies_by_month(df_aq_rs_colo)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Quimioterapias realizadas em Porto Alegre por Mês (2025)\n(Câncer de Colo de Útero)'}, xlabel='Mês de Processamento (2025)', ylabel='Número de Procedimentos'>)

# %%
plot_stacked_chemotherapies_by_month(df_aq_rs_colo, df_aq_rs_mama)
# Out:
# findfont: Failed to find font weight semibold, now using 700.
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Quimioterapias em Porto Alegre por Mês (2025)\nComparativo de Câncer de Mama e Colo de Útero'}, xlabel='Mês de Processamento (2025)', ylabel='Número de Procedimentos'>)

# %%
plot_chemo_residents_vs_non_residents(df_aq_rs_mama)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Quimioterapias em Porto Alegre por Mês (2025)\nAtendimentos a Residentes vs. Não Residentes (Câncer de Mama)'}, xlabel='Mês de Processamento (2025)', ylabel='Número de Procedimentos'>)

# %%
plot_chemo_stage_comparison(df_aq_rs_colo, df_aq_rs_mama)
# Out:
# (<Figure size 1400x700 with 2 Axes>,
#  array([<Axes: title={'center': 'Câncer de Colo de Útero'}>,
#         <Axes: title={'center': 'Câncer de Mama'}>], dtype=object))

# %%
plot_distribuicao_permanencia(df_rd_rs_colo, tipo_cancer="Colo de Útero")
# Out:
# alt.Chart(...)

# %%
plot_distribuicao_permanencia(df_rd_rs_mama, tipo_cancer="Mama")
# Out:
# alt.Chart(...)

# %%
plot_custos_hospitalares(df_rd_rs_mama, "Mama")
# Out:
# alt.Chart(...)
